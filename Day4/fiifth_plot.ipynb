# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# providing it some data regarding plotting of Histogram
blood_sugar = [113,85,90,150,149,88,93,135,80,77,82,179]
blood_sugar_f = [67,98,89,120,133,150,84,69,89,79,120,112,100]

# setting up labels
plt.title("Blood Sugar Analysis")
plt.xlabel('Sugar Range')
plt.ylabel('Total No. of Patients')

# plotting using histogram plt.hist(data)
plt.hist([blood_sugar,blood_sugar_f],bins = [80,100,125,200],rwidth=0.8,color = ['violet','red'],label = ['men','women'],orientation = 'horizontal')

# setting up the legends
plt.legend()

# %%
# plotting using histogram plt.hist(data)
plt.hist([blood_sugar,blood_sugar_f],bins = [80,100,125,200],rwidth=0.8,color = ['violet','red'],label = ['men','women'])
# Out:
# (array([[6., 1., 4.],
#         [4., 4., 2.]]),
#  array([ 80., 100., 125., 200.]),
#  <a list of 2 BarContainer objects>)
